# %%
import pandas as pd
pd.options.display.max_rows = 999

# %%
basic = pd.read_table('https://datasets.imdbws.com/title.basics.tsv.gz')
rating = pd.read_table('https://datasets.imdbws.com/title.ratings.tsv.gz')
y = basic["startYear"]
y = pd.to_numeric(y, errors='coerce')
basic["startYear"] = y
r = rating["averageRating"]
r = pd.to_numeric(r, errors='coerce')
rating["averageRating"] = r
imdb = pd.merge(basic, rating, left_on = "tconst", right_on = "tconst", how = "left")

# %%
imdb.sort_values(by=["numVotes"], axis=0, ascending=False, inplace=True, kind='quicksort', na_position='last')

# %%
y = imdb[(imdb.startYear >= 2000) & (imdb.numVotes >=90000) & (imdb.averageRating >=7.0) & ((imdb.titleType == "tvMiniSeries") | (imdb.titleType == "tvSeries"))]
y
# Out:
#             tconst     titleType                       primaryTitle  \
# 916034   tt0944947      tvSeries                    Game of Thrones
# 876135   tt0903747      tvSeries                       Breaking Bad
# 2280458  tt1520211      tvSeries                   The Walking Dead
# 2237527  tt1475582      tvSeries                           Sherlock
# 4047909  tt4574334      tvSeries                    Stranger Things
# 870869   tt0898266      tvSeries                The Big Bang Theory
# 749826   tt0773262      tvSeries                             Dexter
# 443097   tt0460649      tvSeries              How I Met Your Mother
# 394704   tt0411008      tvSeries                               Lost
# 3066687  tt2356777      tvSeries                     True Detective
# 2602310  tt1856010      tvSeries                     House of Cards
# 437830   tt0455275      tvSeries                       Prison Break
# 5308991  tt7366338  tvMiniSeries                          Chernobyl
# ...

# %%
x = imdb[(imdb.startYear > 2000) & (imdb.numVotes >=100000) & (imdb.averageRating >=7.5) & (imdb.titleType == "movie")]
print(x)
